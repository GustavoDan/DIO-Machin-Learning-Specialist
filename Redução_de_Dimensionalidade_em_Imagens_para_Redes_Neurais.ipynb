# %%
from PIL import Image, ImageFilter
from requests import get
from io import BytesIO

# %%
response =  get("https://img.olhardigital.com.br/wp-content/uploads/2019/11/20191126093552.jpg")
image = Image.open(BytesIO(response.content)).convert("L")
image
# Out:
# <PIL.Image.Image image mode=L size=860x547 at 0x7F36A8F85DC0>

# %%
image.point(lambda x : 255 if x > 110 else 0)
# Out:
# <PIL.Image.Image image mode=L size=860x547 at 0x7F36A8F77B80>
